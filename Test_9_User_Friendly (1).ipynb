# %% [markdown]
# # AUTOMATIC GENERATION OF MDA ANALYSIS FROM REQUIREMENTS

# %% [markdown]
# **First step is to search the Papyrus Requirements model:**

# %%
import shutil
import os

#Make no attention to the "r" character before the directory path's examples. It is only a python syntax so the "\" character can be taken literally.

dir_or = input("Please enter the papyrus model directory path:\n")
# During the developement period the path used was the one from the Papyrus workspace. 
# See example below:
# r'C:\Users\rroja\workspace-papyrus\Sellar\Sellar.uml'
# C:\Users\rroja\Documents\ISAE\Research Project\Papyrus_models\UAV_tools_test_model\UAV_tools_test.uml

dir_target = input("Please crate a directory path to copy the original model file for data management and thus avoid any damage to the model source code.\n"+
                   "Once created please input it below:\n (Please notice that results from OpenMDAO will be stored in a folder created automatically in this directory\n")
#As dir_target the path used was as below. It can be any preferred location.
#dir_target = r'C:\Users\rroja\Documents\ISAE\Research Project\Jupyter_Tests\Copied_uml-to-xml'

#The name of the generated copy is with a direct parse to XML file. model_XML.xml
name='model_XML.xml'
path = os.path.join(dir_target, name)

shutil.copyfile(dir_or, path)
# Out:
# Please enter the papyrus model directory path:
# C:\Users\rroja\Documents\ISAE\Research Project\Papyrus_models\UAV_tools_test_model\UAV_tools_test.uml
# Please crate a directory path to copy the original model file for data management and thus avoid any damage to the model source code.
# Once created please input it below:
#  (Please notice that results from OpenMDAO will be stored in a folder created automatically in this directory
# C:\Users\rroja\Documents\ISAE\Research Project\Jupyter_Tests\Copied_uml-to-xml
# 'C:\\Users\\rroja\\Documents\\ISAE\\Research Project\\Jupyter_Tests\\Copied_uml-to-xml\\model_XML.xml'

# %% [markdown]
# **The xml file is converted to a json file:**

# %%
import json
import xmltodict

with open(r'C:\Users\rroja\Documents\ISAE\Research Project\Jupyter_Tests\Copied_uml-to-xml\model_XML.xml') as xml_file:
    data_dict = xmltodict.parse(xml_file.read())
    xml_file.close()

    json_data = json.dumps(data_dict)
    with open("data.json", "w") as json_file:
        json_file.write(json_data)
        json_file.close()

# %% [markdown]
# **The file is read:**

# %%
# JSON file
f = open ('data.json', "r")
  
# Reading from file
data = json.loads(f.read())
data
# Out:
# {'xmi:XMI': {'@xmi:version': '20131001',
#   '@xmlns:xmi': 'http://www.omg.org/spec/XMI/20131001',
#   '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   '@xmlns:Requirementprofile': 'http:///schemas/Requirementprofile/_nfUwUI9QEeyDkrtcFBe8AA/10',
#   '@xmlns:ecore': 'http://www.eclipse.org/emf/2002/Ecore',
#   '@xmlns:uml': 'http://www.eclipse.org/uml2/5.0.0/UML',
#   '@xsi:schemaLocation': 'http:///schemas/Requirementprofile/_nfUwUI9QEeyDkrtcFBe8AA/10 ../Requirement%20profile/Requirement%20profile.profile.uml#_nfVXYI9QEeyDkrtcFBe8AA',
#   'uml:Model': {'@xmi:id': '_Fwf68C0IEeydKKxpjt4sqQ',
#    '@name': 'Sellar',
#    'packageImport': [{'@xmi:type': 'uml:PackageImport',
#      '@xmi:id': '_F1PRAC0IEeydKKxpjt4sqQ',
#      'importedPackage': {'@xmi:type': 'uml:Model',
#       '@href': 'pathmap://UML_LIBRARIES/UMLPrimitiveTypes.library.uml#_0'}},
#     {'@xmi:type': 'uml:PackageImport',
#      '@xmi:id': '_F1ehkC0IEeydKKxpjt4sqQ',
#      'importedPackage': {'@xmi:type': 'uml:Package',
#       '@href': 'pathmap://SysML16_LIBRARIES/SysML-Standard-Library.uml#SysML.package_packagedElement_Libraries'}}],
#    'packagedElement': [{'@xmi:type': 'uml:Package',
#      '@xmi:id': '_71PkAC0NEey2VL7OA8AAEg',
#      '@name': 'Inputs',
#      'packagedElement': [{'@xmi:type': 'uml:Class',
#        '@xmi:id': '_Dv4fUC0OEey2VL7OA8AAEg',
#        '@name': 'x'},
#       {'@xmi:type': 'uml:Class',
#        '@xmi:id': '_I00Y0C0OEey2VL7OA8AAEg',
#        '@name': 'z1'},
#       {'@xmi:type': 'uml:Class',
#        '@xmi:id': '_Nef5sC0OEey2VL7OA8AAEg',
#        '@name': 'Empennage Weight'}]},
#     {'@xmi:type': 'uml:Package',
#      '@xmi:id': '_lJJxIC0OEey2VL7OA8AAEg',
#      '@name': 'Outputs',
#      'packagedElement': [{'@xmi:type': 'uml:Class',
#        '@xmi:id': '_nrpjEC0OEey2VL7OA8AAEg',
#        '@name': 'g1'},
#       {'@xmi:type': 'uml:Class',
#        '@xmi:id': '_t65TkC0OEey2VL7OA8AAEg',
#        '@name': 'g2'}]}],
#    'profileApplication': [{'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_FyBk8C0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_FyGdcC0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#/'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1HVMC0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1H8QC0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//activities'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_Activities'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1KYgC0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1KYgS0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//allocations'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_Allocations'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1KYgi0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1KYgy0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//blocks'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_Blocks'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1K_kC0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1K_kS0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//constraintblocks'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_ConstraintBlocks'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1LmoC0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1LmoS0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//deprecatedelements'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_DeprecatedElements'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1Lmoi0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1MNsC0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//modelelements'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_ModelElements'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1MNsS0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1MNsi0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//portsandflows'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_Ports_u0026Flows'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1Nb0C0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1Nb0S0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/papyrus/sysml/1.6/SysML#//requirements'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://SysML16_PROFILES/SysML.profile.uml#SysML.package_packagedElement_Requirements'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_F1Nb0i0IEeydKKxpjt4sqQ',
#      'eAnnotations': {'@xmi:type': 'ecore:EAnnotation',
#       '@xmi:id': '_F1OC4C0IEeydKKxpjt4sqQ',
#       '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#       'references': {'@xmi:type': 'ecore:EPackage',
#        '@href': 'http://www.eclipse.org/uml2/5.0.0/UML/Profile/Standard#/'}},
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': 'pathmap://UML_PROFILES/Standard.profile.uml#_0'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_C-En4C0OEey2VL7OA8AAEg',
#      'eAnnotations': [{'@xmi:type': 'ecore:EAnnotation',
#        '@xmi:id': '_C-GdES0OEey2VL7OA8AAEg',
#        '@source': 'PapyrusVersion',
#        'details': [{'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_C-GdEi0OEey2VL7OA8AAEg',
#          '@key': 'Version',
#          '@value': '0.0.12'},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_C-GdEy0OEey2VL7OA8AAEg',
#          '@key': 'Comment',
#          '@value': ''},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_C-GdFC0OEey2VL7OA8AAEg',
#          '@key': 'Copyright',
#          '@value': ''},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_C-GdFS0OEey2VL7OA8AAEg',
#          '@key': 'Date',
#          '@value': '2021-10-14'},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_C-GdFi0OEey2VL7OA8AAEg',
#          '@key': 'Author',
#          '@value': ''}]},
#       {'@xmi:type': 'ecore:EAnnotation',
#        '@xmi:id': '_C-GdEC0OEey2VL7OA8AAEg',
#        '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#        'references': {'@xmi:type': 'ecore:EPackage',
#         '@href': '../Requirements%20Profile/Requirement%20profile.profile.uml#_05ujYC0NEey2VL7OA8AAEg'}}],
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': '../Requirements%20Profile/Requirement%20profile.profile.uml#_wZCfwCHaEeuOJcNZkNT1ng'}},
#     {'@xmi:type': 'uml:ProfileApplication',
#      '@xmi:id': '_8LKugC9vEeyo49mkLDyYGg',
#      'eAnnotations': [{'@xmi:type': 'ecore:EAnnotation',
#        '@xmi:id': '_qa6XtI9QEeyDkrtcFBe8AA',
#        '@source': 'PapyrusVersion',
#        'details': [{'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_qa6XtY9QEeyDkrtcFBe8AA',
#          '@key': 'Version',
#          '@value': '0.0.11'},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_qa6Xto9QEeyDkrtcFBe8AA',
#          '@key': 'Comment',
#          '@value': ''},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_qa6Xt49QEeyDkrtcFBe8AA',
#          '@key': 'Copyright',
#          '@value': ''},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_qa6XuI9QEeyDkrtcFBe8AA',
#          '@key': 'Date',
#          '@value': '2022-02-16'},
#         {'@xmi:type': 'ecore:EStringToStringMapEntry',
#          '@xmi:id': '_qa6XuY9QEeyDkrtcFBe8AA',
#          '@key': 'Author',
#          '@value': ''}]},
#       {'@xmi:type': 'ecore:EAnnotation',
#        '@xmi:id': '_8Lv9UC9vEeyo49mkLDyYGg',
#        '@source': 'http://www.eclipse.org/uml2/2.0.0/UML',
#        'references': {'@xmi:type': 'ecore:EPackage',
#         '@href': '../Requirement%20profile/Requirement%20profile.profile.uml#_nfVXYI9QEeyDkrtcFBe8AA'}}],
#      'appliedProfile': {'@xmi:type': 'uml:Profile',
#       '@href': '../Requirement%20profile/Requirement%20profile.profile.uml#_wZCfwCHaEeuOJcNZkNT1ng'}}]},
#   'Requirementprofile:RequirementPlus': [{'@xmi:id': '_GGntMC0OEey2VL7OA8AAEg',
#     '@base_NamedElement': '_Dv4fUC0OEey2VL7OA8AAEg',
#     '@id': 'x',
#     '@base_Class': '_Dv4fUC0OEey2VL7OA8AAEg',
#     '@Type': 'input'},
#    {'@xmi:id': '_K0DssC0OEey2VL7OA8AAEg',
#     '@base_NamedElement': '_I00Y0C0OEey2VL7OA8AAEg',
#     '@id': 'z1',
#     '@base_Class': '_I00Y0C0OEey2VL7OA8AAEg',
#     '@Type': 'input'},
#    {'@xmi:id': '_PPiZgC0OEey2VL7OA8AAEg',
#     '@base_NamedElement': '_Nef5sC0OEey2VL7OA8AAEg',
#     '@base_Class': '_Nef5sC0OEey2VL7OA8AAEg',
#     '@Type': 'input',
#     '@MDAO_id': ''},
#    {'@xmi:id': '_pm1dYC0OEey2VL7OA8AAEg',
#     '@base_NamedElement': '_nrpjEC0OEey2VL7OA8AAEg',
#     '@id': 'y1',
#     '@base_Class': '_nrpjEC0OEey2VL7OA8AAEg',
#     '@Type': 'constraint',
#     '@Disciplines': 'Disc1,Disc2',
#     '@MDAO_id': 'MTOW',
#     'QoI': '20.0'},
#    {'@xmi:id': '_wST24C0OEey2VL7OA8AAEg',
#     '@base_NamedElement': '_t65TkC0OEey2VL7OA8AAEg',
#     '@id': 'y2',
#     '@base_Class': '_t65TkC0OEey2VL7OA8AAEg',
#     '@Type': 'constraint',
#     '@Disciplines': 'Disc1,Disc2',
#     '@MDAO_id': ''}]}}

# %% [markdown]
# **A dictionary with requirements' xmi:id as keys and id as values:**
#
# It is performend for all requirements so we can later retrieve the actual requirements id liked to MDAO analysis and the corresponding quantity of interest (QoI).
#
# The origin of this step comes from the fact the a requirement name might be different than the given requirement id or variable. Therefore, the Papyrus model' source code gives an indentifier to link each block to its attributes. Thus, the algorithm serves of it to automatically retrieve the wanted information (variable Id towards MDAO and QoI).

# %%
#Constructing the dictionary that gatter the Ids liked to MDAO with the internal papyrus @xmi:id.
id_dict={}

for Requirements in data["xmi:XMI"]["Requirementprofile:RequirementPlus"]:
    id_dict[Requirements.get("@base_NamedElement")]=Requirements.get("@MDAO_id")    

id_dict
# Out:
# {'_Dv4fUC0OEey2VL7OA8AAEg': None,
#  '_I00Y0C0OEey2VL7OA8AAEg': None,
#  '_Nef5sC0OEey2VL7OA8AAEg': '',
#  '_nrpjEC0OEey2VL7OA8AAEg': 'MTOW',
#  '_t65TkC0OEey2VL7OA8AAEg': ''}

# %% [markdown]
# **A dictionary with xmi:id as keys and the requirement block name as values**

# %%
#Constructing the names vs xmi:id dictionary. 
#It will work for simple papyrus models, if ever a complex diagram use the algorithm after parameters diagram.
name_dict={}
for req_block in data["xmi:XMI"]["uml:Model"]['packagedElement']:
    if req_block.get('@xmi:type')=='uml:Package':
        if type(req_block['packagedElement']) == dict:
            name_dict[req_block['packagedElement']['@xmi:id']]=req_block['packagedElement']['@name']
        else:
            for variable in req_block['packagedElement']:
                name_dict[variable.get('@xmi:id')]=variable.get("@name")

name_dict
# Out:
# {'_Dv4fUC0OEey2VL7OA8AAEg': 'x',
#  '_I00Y0C0OEey2VL7OA8AAEg': 'z1',
#  '_Nef5sC0OEey2VL7OA8AAEg': 'Empennage Weight',
#  '_nrpjEC0OEey2VL7OA8AAEg': 'g1',
#  '_t65TkC0OEey2VL7OA8AAEg': 'g2'}

# %%
name_dict
# Out:
# {'_Dv4fUC0OEey2VL7OA8AAEg': 'x',
#  '_I00Y0C0OEey2VL7OA8AAEg': 'z1',
#  '_Nef5sC0OEey2VL7OA8AAEg': 'Empennage Weight',
#  '_nrpjEC0OEey2VL7OA8AAEg': 'g1',
#  '_t65TkC0OEey2VL7OA8AAEg': 'g2'}

# %% [markdown]
# **Creation of the Requirement's dictionary (id: name)**

# %%
#Code to automatically create the requirements dictionary 
#The aim is to verify that the correlation between the information is correct.
Requirements_dict = {}
for xmi_id in id_dict:
    if xmi_id in name_dict.keys():
        
         Requirements_dict[id_dict[xmi_id]]=name_dict[xmi_id]
print(Requirements_dict)
# Out:
# {None: 'z1', '': 'g2', 'MTOW': 'g1'}

# %% [markdown]
# **Generation of a dictionary storing the numerical values of each requirement:**

# %%
# WE SHOULD ADDRESS ONLY THE NEEDED PARAMETERS FROM THE MDAO PROBLEM.
# Below we get all of them that have a "QoI" just to code the case when a req. has not this attribute. 
# This algorithm is thinked mainly for troubleshooting and data analysis.

Parameters_dict = {}
for Requirements in data["xmi:XMI"]["Requirementprofile:RequirementPlus"]:    
    if Requirements.get("QoI")==None:
        print("no quantity of interest")
    else:
        if Requirements.get("@MDAO_id") in Requirements_dict.keys():
            Parameters_dict[Requirements.get("@MDAO_id")] = Requirements["QoI"]

print(Parameters_dict)
# Out:
# no quantity of interest
# no quantity of interest
# no quantity of interest
# no quantity of interest
# {'MTOW': '20.0'}

# %%
#THIS CODE REMPLIES ALL THE REQUIREMENTS DICTIONARY AND PARAMETERS DICTIONARY GENERATION FOR A MORE DIRECT GENERATION.
# It does not depend on the papyrus model complexity but in the naming of the stereotype profile extention.

P_dict={}
for Requirements in data["xmi:XMI"]["Requirementprofile:RequirementPlus"]:
    if Requirements.get("QoI")==None or Requirements.get("@MDAO_id")==None :
        P_dict[Requirements.get("@MDAO_id")]=Requirements.get("QoI")
P_dict
# Out:
# {None: None, '': None}

# %% [markdown]
# **WhatsOpt log in:**

# %%
# Completely necessary
# !pip install -U wop
# Out:
# Requirement already up-to-date: wop in c:\users\rroja\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied, skipping upgrade: Click>=6.7 in c:\users\rroja\anaconda3\lib\site-packages (from wop) (7.1.2)
# Requirement already satisfied, skipping upgrade: openmdao-extensions>=1.0.0 in c:\users\rroja\anaconda3\lib\site-packages (from wop) (1.0.2)
# Requirement already satisfied, skipping upgrade: tomli-w in c:\users\rroja\anaconda3\lib\site-packages (from wop) (1.0.0)
# Requirement already satisfied, skipping upgrade: tomli in c:\users\rroja\anaconda3\lib\site-packages (from wop) (2.0.1)
# Requirement already satisfied, skipping upgrade: requests in c:\users\rroja\anaconda3\lib\site-packages (from wop) (2.24.0)
# Requirement already satisfied, skipping upgrade: openmdao>=3.4.0 in c:\users\rroja\anaconda3\lib\site-packages (from wop) (3.12.0)
# Requirement already satisfied, skipping upgrade: tabulate>=0.8.2 in c:\users\rroja\anaconda3\lib\site-packages (from wop) (0.8.9)
# Requirement already satisfied, skipping upgrade: xdsmjs>=1.0.0 in c:\users\rroja\anaconda3\lib\site-packages (from wop) (1.0.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\rroja\anaconda3\lib\site-packages (from requests->wop) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\rroja\anaconda3\lib\site-packages (from requests->wop) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\rroja\anaconda3\lib\site-packages (from requests->wop) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\rroja\anaconda3\lib\site-packages (from requests->wop) (1.25.9)
# Requirement already satisfied, skipping upgrade: pyparsing in c:\users\rroja\anaconda3\lib\site-packages (from openmdao>=3.4.0->wop) (2.4.7)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in c:\users\rroja\anaconda3\lib\site-packages (from openmdao>=3.4.0->wop) (2.4)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\rroja\anaconda3\lib\site-packages (from openmdao>=3.4.0->wop) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\rroja\anaconda3\lib\site-packages (from openmdao>=3.4.0->wop) (1.5.0)
# Requirement already satisfied, skipping upgrade: pyDOE2 in c:\users\rroja\anaconda3\lib\site-packages (from openmdao>=3.4.0->wop) (1.3.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in c:\users\rroja\anaconda3\lib\site-packages (from networkx>=2.0->openmdao>=3.4.0->wop) (4.4.2)

# %%
#!wop login https://ether.onera.fr/whatsopt

from whatsopt.whatsopt_client import WhatsOpt
wop = WhatsOpt(url="https://ether.onera.fr/whatsopt")
ok = wop.login(echo=True)
# Out:
# Successfully logged into WhatsOpt (https://ether.onera.fr/whatsopt)

# %%
# !wop status
#!wop list
# Out:
# You are logged in https://ether.onera.fr/whatsopt
# No local analysis found
#   (use 'wop list' and 'wop pull <id>' to retrieve an existing analysis)
#   (use 'wop push <analysis.py>' to push from the local OpenMDAO code to the server)

# %% [markdown]
# **Pull of the project storing all the disciplines:**

# %%
Project_Pull = !wop pull --json --project-id 14

Project_Pull_str=Project_Pull[0]

with open("Project_Pull_def.json", "w") as json_file:
    json_file.write(Project_Pull_str)
    json_file.close()
    
import json
# Disciplines JSON file
p = open ('Project_Pull_def.json', "r")
Project_Disc = json.loads(p.read())

print(Project_Disc)
# Out:
# {'name': 'UAV_tools_test', 'created_at': '2022-02-16T16:45:21.813Z', 'owner_email': 'rafael.rojas-cardenas-@student.isae-supaero.fr', 'description': 'Application of methodology on MDA for UAV', 'analyses_attributes': [{'name': 'Masses_Analysis', 'disciplines_attributes': [{'name': '__DRIVER__', 'type': 'null_driver', 'variables_attributes': [{'name': 'Empennage_weight', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Endurance', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Fuselage_weight', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'MTOW', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Nb_engines', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Parachute_weight', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Surface', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Thrust', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}]}, {'name': 'Masses', 'type': 'analysis', 'variables_attributes': [{'name': 'Empennage_weight', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Endurance', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Fuselage_weight', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'MTOW', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Nb_engines', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Parachute_weight', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Surface', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Thrust', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}]}]}, {'name': 'Power_Analysis', 'disciplines_attributes': [{'name': '__DRIVER__', 'type': 'null_driver', 'variables_attributes': [{'name': 'Cx', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Cz', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Engine_efficiency', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Fuselage_area', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Surface', 'io_mode': 'out', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Thrust', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}]}, {'name': 'Power', 'type': 'analysis', 'variables_attributes': [{'name': 'Cx', 'io_mode': 'in', 'shape': '1', 'type': 'Float', 'desc': '', 'units': '', 'active': True, 'distributions_attributes': []}, {'name': 'Cz', 'io_mode': 'in', 'shape': '1', 'type': 'Float',  ...

# %% [markdown]
# **Generation of a list containing all the disciplines from the project:**

# %%
#Creation of the list for all the sub-analysis (Disciplines) in the whatsopt project
Project_Disc_list = []

# %%
#Disciplines parse
for disciplines in Project_Disc['analyses_attributes']:
    Project_Disc_list.append(disciplines)

Project_Disc_list
# Out:
# [{'name': 'Masses_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Empennage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Endurance',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'MTOW',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Nb_engines',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Parachute_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Masses',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Empennage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Endurance',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'MTOW',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Nb_engines',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Parachute_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Power_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Cx',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Engine_efficiency',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_area',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Power',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Cx',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Engine_efficiency',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_area',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Empennage_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Empennage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Empennage',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Empennage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Aero_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cx',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Aero',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cx',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Fuselage_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Fuselage_area',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_length',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Fuselage',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Fuselage_area',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_length',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Mission_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Endurance',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Range',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wind_speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Mission',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Endurance',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Range',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wind_speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]}]

# %% [markdown]
# **Generation of a list of all the disciplines whose outputs are found in the requirements:**

# %%
#Discipline List append algorithm for the outputs variables that are found in the req. diagram.
MDA_Disc_list = []

for Disc in Project_Disc_list:
    for disc_attr in Disc["disciplines_attributes"]:
        if disc_attr['name']+'_Analysis' == Disc['name']:
            for var_attr in disc_attr['variables_attributes']:
                if var_attr['name'] in Parameters_dict.keys() and var_attr['io_mode'] == 'out':
                    if disc_attr['name'] not in MDA_Disc_list:
                        MDA_Disc_list.append(Disc)

                    
MDA_Disc_list
# Out:
# [{'name': 'Masses_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Empennage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Endurance',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'MTOW',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Nb_engines',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Parachute_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Masses',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Empennage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Endurance',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'MTOW',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Nb_engines',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Parachute_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]}]

# %% [markdown]
# **Algorithm to find the disciplines whose outputs are inputs for the disciplines previoulsy found. This algorithm is a loop that finishes when there are no more disciplines to be added to the list.**

# %%
# Searching for inputs in the disciplines that are outputs from others

Inputs_list = []

while(True):

    MDA_list_size_init= len(MDA_Disc_list)

    for Disc in MDA_Disc_list:
        for disc_attr in Disc["disciplines_attributes"]:
            if disc_attr['name']+'_Analysis' == Disc['name']:
                for var_attr in disc_attr['variables_attributes']:
                    if var_attr['io_mode'] == 'in':
                        if var_attr['name'] not in Inputs_list:
                            Inputs_list.append(var_attr['name'])

#Inputs_list

    for Disc in Project_Disc_list:
        for disc_attr in Disc["disciplines_attributes"]:
            if disc_attr['name']+'_Analysis' == Disc['name']:
                for var_attr in disc_attr['variables_attributes']:
                    if var_attr['io_mode'] == 'out':
                        if (var_attr['name'] in Inputs_list) and (Disc not in MDA_Disc_list):
                            MDA_Disc_list.insert(0,Disc)
                
    MDA_list_size_up= len(MDA_Disc_list)

    if MDA_list_size_up != MDA_list_size_init:
        MDA_list_size_init = MDA_list_size_up
        continue
    else:
        break

# %%
MDA_Disc_list
# Out:
# [{'name': 'Mission_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Endurance',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Range',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wind_speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Mission',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Endurance',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Range',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wind_speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Fuselage_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Fuselage_area',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_length',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Fuselage',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Fuselage_area',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_length',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Aero_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cx',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Aero',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cx',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Speed',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Empennage_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Empennage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Empennage',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Chord',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Empennage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_HT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'L_VT',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Wing_span',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Power_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Cx',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Engine_efficiency',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_area',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Power',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Cx',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Cz',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Engine_efficiency',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_area',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]},
#  {'name': 'Masses_Analysis',
#   'disciplines_attributes': [{'name': '__DRIVER__',
#     'type': 'null_driver',
#     'variables_attributes': [{'name': 'Empennage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Endurance',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'MTOW',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Nb_engines',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Parachute_weight',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]},
#    {'name': 'Masses',
#     'type': 'analysis',
#     'variables_attributes': [{'name': 'Empennage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Endurance',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Fuselage_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'MTOW',
#       'io_mode': 'out',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Nb_engines',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Parachute_weight',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Surface',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []},
#      {'name': 'Thrust',
#       'io_mode': 'in',
#       'shape': '1',
#       'type': 'Float',
#       'desc': '',
#       'units': '',
#       'active': True,
#       'distributions_attributes': []}]}]}]

# %% [markdown]
# **Generation of the MDA json file to be pushed:
# First a list of all the variables of the analysis**

# %%
list_of_variables=[]


#we start to append all "out" variables in the list without any change.
for Disc in MDA_Disc_list:
    for disc_attr in Disc["disciplines_attributes"]:
        if disc_attr['name']+'_Analysis' == Disc['name']:
            for var_attr in disc_attr['variables_attributes']:
                if var_attr['name'] in [v_dict['name'] for v_dict in list_of_variables]:
                    print('repeated variable')
                elif var_attr['io_mode'] == 'out':
                    list_of_variables.append(var_attr)
# Out:
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable

# %%
   
# Now we have to search all the "in" variables for each discipline leaving outside all previous "out" variables.


for Disc in MDA_Disc_list:
    for disc_attr in Disc["disciplines_attributes"]:
        if disc_attr['name']+'_Analysis' == Disc['name']:
            for var_attr in disc_attr['variables_attributes']:
                if var_attr['name'] in [v_dict['name'] for v_dict in list_of_variables]:
                    print('repeated variable')
                else:
                    Inputs_list.append(var_attr)
                    list_of_variables.append(var_attr)
                
list_of_variables
# Out:
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# repeated variable
# [{'name': 'Endurance',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Fuselage_area',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Fuselage_weight',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'L_HT',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'L_VT',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Chord',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Cx',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Cz',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Surface',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Empennage_weight',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Thrust',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'MTOW',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Range',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Speed',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Wind_speed',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Fuselage_length',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Wing_span',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Engine_efficiency',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Nb_engines',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Parachute_weight',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []}]

# %% [markdown]
# **The QoI is inserted to those variables that are found in the Parameters_dict.**

# %%
#Algorithm to modify the top level DRIVER variables.

init_value_template = {'init': None, 'lower': None, 'upper': None}


for var in list_of_variables:
    if var['name'] in Parameters_dict.keys():
        init_value_template['init']=Parameters_dict.get(var['name'])
        var['parameter_attributes']=init_value_template
        init_value_template = {'init': None, 'lower': None, 'upper': None}
        
list_of_variables
# Out:
# [{'name': 'Endurance',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Fuselage_area',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Fuselage_weight',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'L_HT',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'L_VT',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Chord',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Cx',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Cz',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Surface',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Empennage_weight',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Thrust',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'MTOW',
#   'io_mode': 'out',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': [],
#   'parameter_attributes': {'init': '20.0', 'lower': None, 'upper': None}},
#  {'name': 'Range',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Speed',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Wind_speed',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Fuselage_length',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Wing_span',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Engine_efficiency',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Nb_engines',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []},
#  {'name': 'Parachute_weight',
#   'io_mode': 'in',
#   'shape': '1',
#   'type': 'Float',
#   'desc': '',
#   'units': '',
#   'active': True,
#   'distributions_attributes': []}]

# %%
#Algorithm to modify the local discipline Driver.

init_value_template = {'init': None, 'lower': None, 'upper': None}

for Disc in Project_Disc_list:
    for disc_attr in Disc["disciplines_attributes"]:
        if disc_attr['name'] == '__DRIVER__':
            for var_attr in disc_attr['variables_attributes']:
                if var_attr['name'] in Parameters_dict.keys():
                    init_value_template['init']=Parameters_dict.get(var_attr['name'])
                    var_attr['parameter_attributes']=init_value_template
                    init_value_template = {'init': None, 'lower': None, 'upper': None}
                    
#Project_Disc_list

# %% [markdown]
# **For the Driver, the io_mode needs to be switched:**
# If the variables are an output from a discipline they shall be treated as "input" in the driver and viceversa.
# Notice that a "new_list" is needed in order to make a "deep copy" and do not modify the original format."

# %%
import copy
new_list = copy.deepcopy(list_of_variables)
for instance in new_list:
    if instance['io_mode'] == 'out':
        instance['io_mode'] = 'in'
    elif instance['io_mode'] == 'in':
        instance['io_mode'] = 'out'
#new_list

# %% [markdown]
# **Insert into the json file the list of variables:**
#
# First we start to generate the format for the DRIVER

# %%
DRONE_MDA_push = {'name': 'DRONE_Reference_push', 
             'disciplines_attributes': [{
                 'name': '__DRIVER__', 
                 'type': 'null_driver',
                 'variables_attributes':[]}]}

DRONE_MDA_push['disciplines_attributes'][0]['variables_attributes'] = new_list
#DRONE_MDA_push

# %% [markdown]
# **Insert the disciplines:**

# %%
for disc in MDA_Disc_list:
    DRONE_MDA_push['disciplines_attributes'].append({'name': disc['name'],'type': 'mda', 'sub_analysis_attributes': disc})

#DRONE_MDA_push

# %% [markdown]
# **Convert json file into a string so as to be pushed to WhatsOpt:**

# %%
string_problem_mod = json.dumps(DRONE_MDA_push)
Problem_json=[]
Problem_json.append(string_problem_mod)
#Problem_json

# %% [markdown]
# **Push into WhatsOpt:**

# %%
with open("problem_definition_mod.json", "w") as json_file:
    json_file.write(string_problem_mod)
    json_file.close()
# !wop push --json problem_definition_mod.json
# Out:
# Analysis DRONE_Reference_push pushed

# %% [markdown]
# **Pulling the analysis to run it**

# %%
#Getting the last modified project id
owned_project_list = !wop list
last_project=owned_project_list[len(owned_project_list)-2]
lp_list=last_project.split(' ')
lp_id=lp_list[0]
lp_id
# Out:
# '1670'

# %%
#Pulling the last modified project
newpath = r''+dir_target+''+'\OpenMDAO_Files\\'+lp_id
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
# !dir
# Out:
#  El volumen de la unidad C es Windows
#  El número de serie del volumen es: DAFC-E9CF
#
#  Directorio de C:\Users\rroja\Documents\ISAE\Research Project\Jupyter_Tests\Copied_uml-to-xml\OpenMDAO_Files\1670
#
# 09/03/2022  04:23 p. m.    <DIR>          .
# 09/03/2022  04:23 p. m.    <DIR>          ..
#                0 archivos              0 bytes
#                2 dirs  38,768,828,416 bytes libres

# %%
#How to automatically pull the lastest modification of the project.

cmd_lp = "wop pull " + lp_id

import subprocess
subprocess.run(cmd_lp, shell=True, check=True)
# Out:
# CompletedProcess(args='wop pull 1670', returncode=0)

# %%
# %run run_mda.py
# Out:
# |
# |  =================
# |  fuselage_analysis
# |  =================
# |  NL: NLBGS Converged in 1 iterations
# |
# |  =============
# |  aero_analysis
# |  =============
# |  NL: NLBGS Converged in 1 iterations
# |
# |  ==================
# |  empennage_analysis
# |  ==================
# |  NL: NLBGS Converged in 2 iterations
# |
# |  =================
# |  fuselage_analysis
# |  =================
# |  NL: NLBGS Converged in 1 iterations
# |
# |  =============
# |  aero_analysis
# |  =============
# |  NL: NLBGS Converged in 1 iterations
# |
# |  ==================
# |  empennage_analysis
# |  ==================
# |  NL: NLBGS Converged in 1 iterations
# NL: NLBGS Converged in 2 iterations
# 9 Input(s) in 'model'
#
# varname              val
# -------------------  ----
# fuselage_analysis
#   fuselage
#     Fuselage_length  [1.]
#     Speed            [1.]
# aero_analysis
#   aero
#     Speed            [1.]
#     Wing_span        [1.]
# empennage_analysis
#   empennage
#     Chord            [1.]
#     L_HT             [1.]
#     L_VT             [1.]
#     Surface          [1.]
#     Wing_span        [1.]
#
#
# 9 Explicit Output(s) in 'model'
#
# varname               val
# --------------------  ----
# fuselage_analysis
#   fuselage
#     Fuselage_area     [1.]
#     Fuselage_weight   [1.]
#     L_HT              [1.]
#     L_VT              [1.]
# aero_analysis
#   aero
#     Chord             [1.]
#     Cx                [1.]
#     Cz                [1.]
#     Surface           [1.]
# empennage_analysis
#   empennage
#     Empennage_weight  [1.]
#
#
# 0 Implicit Output(s) in 'model'

# %%
#!wop -h
